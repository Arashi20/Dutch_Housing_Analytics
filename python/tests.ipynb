# %% [markdown]
# # Quick Test Scripts

# %% [markdown]
# ### Testing out the Feed API for bulk download

# %%
# Quick test in Python console or notebook:
import requests

# Test if Feed API accepts large query
url = "https://opendata.cbs.nl/ODataFeed/odata/82211NED/TypedDataSet"
params = {
    "$format": "json",
    "$filter": "Perioden ge '2015MM01' and Perioden le '2015MM12'",  # 1 year
    "$top": 20000  # More than Standard API limit!
}

response = requests.get(url, params=params)
print(f"Status: {response.status_code}")
print(f"Rows: {len(response.json()['value'])}")

# If this works (status 200, >10k rows), Feed API is the solution!
# Out:
# Status: 200
# Rows: 10000

# %% [markdown]
# ### Quickly check both datasets

# %%
import pandas as pd
import os

# Load datasets
df_doorloop = pd.read_csv(os.path.join("..", "data", "processed", "doorlooptijden_latest.csv"))
df_pijplijn = pd.read_csv(os.path.join("..", "data", "processed", "woningen_pijplijn_latest.csv"))

print("="*70)
print("DATASET 1: DOORLOOPTIJDEN - COLUMNS")
print("="*70)
print(df_doorloop.columns.tolist())
print(f"\nFirst 5 rows:")
print(df_doorloop.head())

print("\n" + "="*70)
print("DATASET 2: WONINGEN PIJPLIJN - COLUMNS")
print("="*70)
print(df_pijplijn.columns.tolist())
print(f"\nFirst 5 rows:")
print(df_pijplijn.head())
# Out:
# ======================================================================
# DATASET 1: DOORLOOPTIJDEN - COLUMNS
# ======================================================================
# ['ID', 'Regiokenmerken', 'Gebruiksfunctie', 'Woningtype', 'Perioden', 'Doorlooptijd_Mediaan', 'Doorlooptijd_Gemiddelde', 'Doorlooptijd_P10', 'Doorlooptijd_P25', 'Doorlooptijd_P75', 'Doorlooptijd_P90', 'Nieuwbouw_Aantal', 'Regio_Naam', 'Gebruiksfunctie_Naam', 'Woningtype_Naam', 'Periode_Naam', 'Jaar', 'Kwartaal', 'Doorlooptijd_IQR', 'Doorlooptijd_P10_P90_Range', 'Hoge_Variabiliteit', 'Doorlooptijd_CV']
#
# First 5 rows:
#    ID Regiokenmerken Gebruiksfunctie Woningtype  Perioden  \
# 0   0        NL01            T001419    T001100  2015KW01
# 1   1        NL01            T001419    T001100  2015KW02
# 2   2        NL01            T001419    T001100  2015KW03
# 3   3        NL01            T001419    T001100  2015KW04
# 4   5        NL01            T001419    T001100  2016KW01
#
#    Doorlooptijd_Mediaan  Doorlooptijd_Gemiddelde  Doorlooptijd_P10  \
# 0                  18.6                     21.8               7.1
# 1                  15.1                     19.0               7.9
# 2                  17.0                     19.8               7.8
# 3                  14.7                     18.6               8.1
# 4                  15.4                     18.7               9.1
#
#    Doorlooptijd_P25  Doorlooptijd_P75  ...  Regio_Naam  \
# 0              11.8              29.3  ...   Nederland
# 1              10.1              24.3  ...   Nederland
# 2              11.4              24.3  ...   Nederland
# 3              10.8              22.0  ...   Nederland
# 4              11.5              21.5  ...   Nederland
#
#            Gebruiksfunctie_Naam Woningtype_Naam      Periode_Naam  Jaar  \
# 0  Woning en niet-woning totaal          Totaal  2015 1e kwartaal  2015
# 1  Woning en niet-woning totaal          Totaal  2015 2e kwartaal  2015
# 2  Woning en niet-woning totaal          Totaal  2015 3e kwartaal  2015
# 3  Woning en niet-woning totaal          Totaal  2015 4e kwartaal  2015
# 4  Woning en niet-woning totaal          Totaal  2016 1e kwartaal  2016
#
#   Kwartaal  Doorlooptijd_IQR  Doorlooptijd_P10_P90_Range  Hoge_Variabiliteit  \
# 0        1              17.5                        38.5                   1
# 1        2              14.2                        28.0                   1
# 2        3              12.9                        29.5                   1
# 3        4              11.2                        29.4                   1
# 4        1              10.0                        24.2                   0
#
#    Doorlooptijd_CV
# 0         0.940860
# 1         0.940397
# 2         0.758824
# 3         0.761905
# 4         0.649351
#
# [5 rows x 22 columns]
#
# ======================================================================
# DATASET 2: WONINGEN PIJPLIJN - COLUMNS
# ======================================================================
# ['ID', 'Gebruiksfunctie', 'RegioS', 'Perioden', 'Pijplijn_Totaal', 'Pijplijn_BouwGestart', 'Pijplijn_Vergunning', 'Pijplijn_Vast_2Jaar', 'Pijplijn_BouwGestart_2Jaar', 'Pijplijn_Vergunning_2Jaar', 'Pijplijn_Vast_5Jaar', 'BouwGestartPijplijn5Jaar_8', 'Vergunningspijplijn5Jaar_9', 'Regio_Naam', 'Gebruiksfunctie_Naam', 'Periode_Naam', 'Jaar', 'Maand', 'Bottleneck_2Jaar_Pct', 'Bottleneck_5Jaar_Pct', 'Vergunning_Bottleneck_Pct', 'Bouw_Bottleneck_Pct', 'Vergunning_Fase_Pct', 'Bouw_Fase_Pct', 'Crisis_Regio']
#
# First 5 rows:
#       ID Gebruiksfunctie RegioS  Perioden  Pijplijn_Totaal  \
# 0  88825         A045364   NL01  2015MM01         107291.0
# 1  88826         A045364   NL01  2015MM02         110504.0
# 2  88827         A045364   NL01  2015MM03         114262.0
# 3  88828         A045364   NL01  2015KW01         114262.0
# 4  88829         A045364   NL01  2015MM04         116950.0
#
#    Pijplijn_BouwGestart  Pijplijn_Vergunning  Pijplijn_Vast_2Jaar  \
# 0               39551.0              67740.0              39518.0
# 1               38919.0              71585.0              39406.0
# 2               39445.0              74817.0              38009.0
# 3               39445.0              74817.0              38009.0
# 4               39691.0              77259.0              37414.0
#
#    Pijplijn_BouwGestart_2Jaar  Pijplijn_Vergunning_2Jaar  ...  \
# 0                      6490.0                    27003.0  ...
# 1                      6477.0                    26686.0  ...
# 2                      6123.0                    25965.0  ...
# 3                      6123.0                    25965.0  ...
# 4                      6271.0                    25637.0  ...
#
#        Periode_Naam  Jaar  Maand Bottleneck_2Jaar_Pct Bottleneck_5Jaar_Pct  \
# 0      2015 januari  2015      1            36.832540             6.926024
# 1     2015 februari  2015      2            35.660248             6.632339
# 2        2015 maart  2015      3            33.264777             6.857923
# 3  2015 1e kwartaal  2015      1            33.264777             6.857923
# 4        2015 april  2015      4            31.991449             6.678923
#
#   Vergunning_Bottleneck_Pct  Bouw_Bottleneck_Pct  Vergunning_Fase_Pct  \
# 0                 39.862710            16.409193            63.136703
# 1                 37.278760            16.642257            64.780460
# 2                 34.704679            15.522880            65.478462
# 3                 34.704679            15.522880            65.478462
# 4                 33.183189            15.799552            66.061565
#
#    Bouw_Fase_Pct  Crisis_Regio
# 0      36.863297             1
# 1      35.219540             1
# 2      34.521538             1
# 3      34.521538             1
# 4      33.938435             1
#
# [5 rows x 25 columns]

# %%
import pandas as pd
import os

# Load both datasets
df_doorloop = pd.read_csv(os.path.join("..", "data", "processed", "doorlooptijden_latest.csv"))
df_pijplijn = pd.read_csv(os.path.join("..", "data", "processed", "woningen_pijplijn_latest.csv"))

print("="*70)
print("DATASET 1: DOORLOOPTIJDEN")
print("="*70)
print(f"Rows: {len(df_doorloop):,}")
print(f"Columns: {len(df_doorloop.columns)}")
print(f"Year range: {df_doorloop['Jaar'].min()}-{df_doorloop['Jaar'].max()}")  # 'Jaar' met hoofdletter
print(f"Unique regio's: {df_doorloop['Regio_Naam'].nunique()}")
print(f"Avg median doorlooptijd: {df_doorloop['Doorlooptijd_Mediaan'].mean():.1f} maanden")  # Doorlooptijd_Mediaan

print("\n" + "="*70)
print("DATASET 2: WONINGEN PIJPLIJN")
print("="*70)
print(f"Rows: {len(df_pijplijn):,}")
print(f"Columns: {len(df_pijplijn.columns)}")
print(f"Year range: {df_pijplijn['Jaar'].min()}-{df_pijplijn['Jaar'].max()}")  # 'Jaar' met hoofdletter
print(f"Unique gemeentes: {df_pijplijn['Regio_Naam'].nunique()}")
print(f"Avg bottleneck (>2yr): {df_pijplijn['Bottleneck_2Jaar_Pct'].mean():.1f}%")  # Bottleneck_2Jaar_Pct
print(f"Avg in vergunningsfase: {df_pijplijn['Vergunning_Fase_Pct'].mean():.1f}%")  # Vergunning_Fase_Pct

print("\n" + "="*70)
print("FASE 1 COMPLEET! ✓")
print("="*70)
# Out:
# ======================================================================
# DATASET 1: DOORLOOPTIJDEN
# ======================================================================
# Rows: 9,234
# Columns: 22
# Year range: 2015-2025
# Unique regio's: 19
# Avg median doorlooptijd: 19.1 maanden
#
# ======================================================================
# DATASET 2: WONINGEN PIJPLIJN
# ======================================================================
# Rows: 88,825
# Columns: 25
# Year range: 2015-2025
# Unique gemeentes: 415
# Avg bottleneck (>2yr): 20.8%
# Avg in vergunningsfase: 51.6%
#
# ======================================================================
# FASE 1 COMPLEET! ✓
# ======================================================================
